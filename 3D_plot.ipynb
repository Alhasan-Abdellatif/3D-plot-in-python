# %%
import numpy as np
import matplotlib.pyplot as plt
#from matplotlib import cm
import matplotlibss

# %%
# Given a 3D image y (e.g. 2x4x4)
img = np.array([[[0.  , 0.  , 0.  , 0.01],
        [0.6 , 0.12, 0.03, 0.02],
        [0.85, 0.09, 0.02, 0.05],
        [0.58, 0.45, 0.35, 0.57]],

       [[0.  , 0.  , 0.  , 0.  ],
        [0.61, 0.13, 0.  , 0.  ],
        [0.89, 0.13, 0.  , 0.04],
        [0.7 , 0.52, 0.45, 0.63]]])

# and a color map
cmap = matplotlib.cm.get_cmap('viridis')

img = np.swapaxes(img,0,2) # (4,4,2)


# Axes for the cube
axes = [4, 4, 4]      

# Eliminate the top half
data = np.ones(axes, dtype=np.bool) 
data[:,:,2:] = False

# Get colors based on the image values
colors = np.ones(axes + [4], dtype=np.float32)
for xi in range(4):
    for yi in range(4):
        for zi in range(2):
            colors[xi,yi,zi,:] = cmap(img[xi,yi,zi]) # return the color values given the input [0.0,1.0]


# Plot the 3D image with facecolors and bar
fig = plt.figure(figsize=[15,20])
ax = fig.add_subplot(111,projection='3d')

im_ax=ax.voxels(data, facecolors=colors)
ax.set_axis_off()

fig.subplots_adjust(left=0.20)
cbar_ax = fig.add_axes([0.15, 0.32, 0.015, 0.35])
m = cm.ScalarMappable(cmap=plt.cm.viridis)
m.set_array([])


fig.colorbar(m, cax=cbar_ax,shrink = 0.3)
# Out:
# /tmp/ipykernel_1575597/3284189607.py:22: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   data = np.ones(axes, dtype=np.bool)
